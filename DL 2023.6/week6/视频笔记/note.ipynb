# %% [markdown]
# <a href="https://colab.research.google.com/github/ldm2060/LearningNote/blob/main/DL%202023.6/week6/%E8%A7%86%E9%A2%91%E7%AC%94%E8%AE%B0/note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WEEK 6  Self-Supervised Learning
#
# - The models become larger and larger …

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Masking Input（如BERT）：Randomly masking some tokens
#
# Masking 做法：用特定符号遮住（special token）或者是用随机字符替换

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Downstream Tasks :
# - the task you really want to solve
# - better than directly using labeld data
# - We have a little bit labeled data.
#
# 测试：General Language Understanding Evaluation (GLUE)
# - Corpus of Linguistic Acceptability (CoLA)：Each example is a sequence of words annotated with whether it is a grammatical English sentence
# - Stanford Sentiment Treebank (SST-2)
# - Microsoft Research Paraphrase Corpus (MRPC)：with human annotations for whether the sentences in the pair are semantically equivalent
# - Quora Question Pairs (QQP)：determine whether a pair of questions are semantically equivalent.
# - Semantic Textual Similarity Benchmark (STS-B)：Each pair is human-annotated with a similarity score from 1 to 5; the task is to predict these scores
# - Multi-Genre Natural Language Inference (MNLI)
# - Question-answering NLI (QNLI)
# - Recognizing Textual Entailment (RTE)
# - Winograd NLI (WNLI)
#
# How to use BERT （semi-supervised）
#
# - Case 1：input:  sequence and output: class
# - Case 2：Input: sequence, output: same as input
# - Case 3：(Input: two sequences，Output: a class
# - Case 4：Extraction-based Question Answering (QA)
#
#
#
#   Pre-train(fine-tune) v.s. Random Initialization (scratch)

# %% [markdown]
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# Why does BERT work?
# - The tokens with similar meaning have similar embedding.
#
#   (如下图所示词句相似度，越黄越好，模型会参考上下文)
# - You shall know a word by the company it keeps

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Zero-shot Reading Comprehension
# - English: SQuAD, Chinese: DRCD
# - F1 score of Human performance is 93.30%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The training is also challenging …

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 多语言模型中，不同语言的input embedding向量间有差距，如果把某个语言的embedding加上统计的差距，会得到什么？
#
# 期望：

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 实际：

# %% [markdown]
# ![image.png](data:image/png;base64,...)
