# %% [markdown]
# <a href="https://colab.research.google.com/github/ldm2060/LearningNote/blob/main/DL%202023.6/week7/%E8%A7%86%E9%A2%91%E7%AC%94%E8%AE%B0/note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WEEK 7
#
# ## 7.1 ChatGPT原理
#
# ChatGPT 真正做的事 – 文字接龙

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 自监督学习：網路上每一段文字都可以教機器做文字接龍

# %% [markdown]
# ## 7.2 生成式学习的两种不同策略
#
# - 策略一：各个击破 ： Autoregressive (AR) model
# - 策略二：一次到位 Non-autoregressive (NAR) model

# %% [markdown]
# ## 7.3 Finetune vs. Prompt
# - 成為專才的好處：專才在單一任務上有機會贏過通才
# - 成為通才的好處：只要重新設計 prompt 就可以快速開發新功能，不用寫程式
#
# 微調 (Finetune)：Update network parameters by gradient descent
#
# Prompt：機器要學會讀題目敘述或題目範例
#
# 给错误例子模型也能完成任务，这证明：本來就會做情感分析，只是需要被指出需要做情感任務
#
# Instruction-tuning：告诉模型要什么样的结果
#
# Chain of Thought (CoT) Prompting：告诉模型推导过程

# %% [markdown]
# ## 7.4 大模型+大資料=神奇力量
#
# 大模型的頓悟時刻

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# U-shaped? 一知半解吃大虧

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 還能不能更大？
#
# 如 Switch Transformer：1.6T
#
# 大資料的重要性

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Chinchilla (小模型、大資料) vs. Gopher (大模型、小資料)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 模型也许已经足够大了，需要的是更多的训练资料（比如GPT-3的训练资料是不够的）
